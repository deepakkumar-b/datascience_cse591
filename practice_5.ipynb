# %% [raw]
# Question 5
#
# (5) Set up a meaningful distance function to measure how similar/difference pairs of countries are.
#
# Produce a table showing the nearest and farthest neighbor to each nation on earth?
#
# Write a short analysis of this table describing: (a) What kinds of similarities does your measure get right? (b) What are the most interesting/surprising pairs to fall out of this analysis? and (c) Where does it goof up?

# %% [raw]
# Reference : http://nbviewer.ipython.org/github/robertodealmeida/notebooks/blob/master/adcp/ACC.ipynb

# %%
import pandas as pd

dfCountries = pd.read_csv('countries.csv') 
Countries = pd.read_csv('countries.csv')

# %%
from math import sin, cos, sqrt, atan2, radians
#distance calculations
def findDistance(lat1,lon1,lat2,lon2,R=6373.0):
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = (sin(dlat/2))**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    return distance

#Build a pairwise countries DataFrame
Columns = ['Country Name','Latitude of Capital', 'Longitude of Capital']

dfDistance = pd.DataFrame(data=None, columns=['Country1','Country2','Distance','Population_','Life_','literacy_','GDP_','Health_','Military_','Water_'])

for i in arange(len(Countries.index)):
    src_country = Countries.loc[i,Columns[0]]
    src_lat = Countries.loc[i,Columns[1]]
    src_lon = Countries.loc[i,Columns[2]]
    
    for j in arange(len(Countries.index)):
        dest_country = Countries.loc[j,Columns[0]]
        dest_lat = Countries.loc[j,Columns[1]]
        dest_lon = Countries.loc[j,Columns[2]]
        lat1 = math.radians(conversion(str(src_lat)))
        lon1 = math.radians(str(src_lon))
        lat2 = math.radians(str(dest_lat))
        lon2 = math.radians(str(dest_lon))
        
        '''
        lat1 = math.radians((str(src_lat))
        lon1 = math.radians(conversion(str(src_lon)))
        lat2 = math.radians(conversion(str(dest_lat)))
        lon2 = math.radians(conversion(str(dest_lon)))
        '''
        
        pop = long(Countries[Countries['Country Name']==src_country]['Population']) - long(Countries[Countries['Country Name']==dest_country]['Population'])
        life = long(Countries[Countries['Country Name']==src_country]['Life Expectancy']) - long(Countries[Countries['Country Name']==dest_country]['Life Expectancy'])
        lit = long(Countries[Countries['Country Name']==src_country]['Literacy Rate']) - long(Countries[Countries['Country Name']==dest_country]['Literacy Rate'])
        gdp = long(Countries[Countries['Country Name']==src_country]['GDP (PPP) in US $']) - long(Countries[Countries['Country Name']==dest_country]['GDP (PPP) in US $'])
        health = long(Countries[Countries['Country Name']==src_country]['Health Expenditure/GDP']) - long(Countries[Countries['Country Name']==dest_country]['Health Expenditure/GDP'])
        military = long(Countries[Countries['Country Name']==src_country]['Military Expenditure/GDP']) - long(Countries[Countries['Country Name']==dest_country]['Military Expenditure/GDP'])
        water = long(Countries[Countries['Country Name']==src_country]['Renewable Water Resources (cu km)']) - long(Countries[Countries['Country Name']==dest_country]['Renewable Water Resources (cu km)'])
        ans = np.asarray([src_country, dest_country,float(findDistance(lat1,lon1,lat2,lon2)), pop,life,lit,gdp,health, military,water])
        distance_.loc[len(distance_)+1] = ans
        #print(src_country, dest_country,findDistance(lat1,lon1,lat2,lon2))
distance_ = distance_[distance_['Country1']!=distance_['Country2']].sort(columns='Distance')
print ("Distance Table")
distance_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-347d9c73c423> in <module>()
#      23         dest_lat = Countries.loc[j,Columns[1]]
#      24         dest_lon = Countries.loc[j,Columns[2]]
# ---> 25         lat1 = math.radians(conversion(str(src_lat)))
#      26         lon1 = math.radians(str(src_lon))
#      27         lat2 = math.radians(str(dest_lat))
#
# NameError: name 'conversion' is not defined

# %%
from math import sin, cos, sqrt, atan2, radians
#distance calculations
def findDistance(lat1,lon1,lat2,lon2,R=6373.0):
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = (sin(dlat/2))**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    return distance

#Build a pairwise countries DataFrame
targetColumns = [ \
                 'Country Name', \
                 'Latitude of Capital', \
                 'Longitude of Capital'\
                ]
dfDistance = pd.DataFrame(data=None, columns=['Country1','Country2','Distance',\
                                              'PopulationDiff','literacyDiff','GDPDiff',\
                                              'LifeExpDiff','HealthDiff','MilitaryDiff','WaterDiff'])

for i in arange(len(dfCountries.index)):
    src_country = dfCountries.loc[i,targetColumns[0]]
    src_lat = dfCountries.loc[i,targetColumns[1]]
    src_lon = dfCountries.loc[i,targetColumns[2]]
    #print(i)
    for j in arange(len(dfCountries.index)):
        dest_country = dfCountries.loc[j,targetColumns[0]]
        dest_lat = dfCountries.loc[j,targetColumns[1]]
        dest_lon = dfCountries.loc[j,targetColumns[2]]
        lat1 = math.radians(conversion(str(src_lat)))
        lon1 = math.radians(conversion(str(src_lon)))
        lat2 = math.radians(conversion(str(dest_lat)))
        lon2 = math.radians(conversion(str(dest_lon)))
        
        popDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Population']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Population'])
        literacyDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Literacy Rate']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Literacy Rate'])
        gdpDiff = long(dfCountries[dfCountries['Country Name']==src_country]['GDP (PPP) in US $']) - long(dfCountries[dfCountries['Country Name']==dest_country]['GDP (PPP) in US $'])
        lifeDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Life Expectancy']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Life Expectancy'])
        healthDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Health Expenditure/GDP']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Health Expenditure/GDP'])
        militaryDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Military Expenditure/GDP']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Military Expenditure/GDP'])
        waterDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Renewable Water Resources (cu km)']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Renewable Water Resources (cu km)'])
        
        #temp = np.asarray([src_country, dest_country,float(findDistance(lat1,lon1,lat2,lon2))])
        temp = np.asarray([src_country, dest_country,float(findDistance(lat1,lon1,lat2,lon2)), popDiff,literacyDiff,gdpDiff,lifeDiff,healthDiff,militaryDiff,waterDiff])
        
        dfDistance.loc[len(dfDistance)+1] = temp
        #print(src_country, dest_country,findDistance(lat1,lon1,lat2,lon2))
dfDistance = dfDistance[dfDistance['Country1']!=dfDistance['Country2']].sort(columns='Distance')
print ("Distance Table")
dfDistance

# %%
from math import sin, cos, sqrt, atan2, radians
#distance calculations
def findDistance(lat1,lon1,lat2,lon2,R=6373.0):
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = (sin(dlat/2))**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    return distance

#Build a pairwise countries DataFrame
Columns = ['Country Name','Latitude of Capital', 'Longitude of Capital']

dfDistance = pd.DataFrame(data=None, columns=['Country1','Country2','Distance','Population_','Life_','literacy_','GDP_','Health_','Military_','Water_'])

for i in arange(len(Countries.index)):
    src_country = Countries.loc[i,Columns[0]]
    src_lat = Countries.loc[i,Columns[1]]
    src_lon = Countries.loc[i,Columns[2]]
    
    for j in arange(len(Countries.index)):
        dest_country = Countries.loc[j,Columns[0]]
        dest_lat = Countries.loc[j,Columns[1]]
        dest_lon = Countries.loc[j,Columns[2]]
        lat1 = math.radians(conversion(str(src_lat)))
        lon1 = math.radians(conversion(str(src_lon)))
        lat2 = math.radians(conversion(str(dest_lat)))
        lon2 = math.radians(conversion(str(dest_lon)))
        
        pop = long(Countries[Countries['Country Name']==src_country]['Population']) - long(Countries[Countries['Country Name']==dest_country]['Population'])
		life = long(Countries[Countries['Country Name']==src_country]['Life Expectancy']) - long(Countries[Countries['Country Name']==dest_country]['Life Expectancy'])
        
		lit = long(Countries[Countries['Country Name']==src_country]['Literacy Rate']) - long(Countries[Countries['Country Name']==dest_country]['Literacy Rate'])
        gdp = long(Countries[Countries['Country Name']==src_country]['GDP (PPP) in US $']) - long(Countries[Countries['Country Name']==dest_country]['GDP (PPP) in US $'])
        
        health = long(Countries[Countries['Country Name']==src_country]['Health Expenditure/GDP']) - long(Countries[Countries['Country Name']==dest_country]['Health Expenditure/GDP'])
        military = long(Countries[Countries['Country Name']==src_country]['Military Expenditure/GDP']) - long(Countries[Countries['Country Name']==dest_country]['Military Expenditure/GDP'])
        water = long(Countries[Countries['Country Name']==src_country]['Renewable Water Resources (cu km)']) - long(Countries[Countries['Country Name']==dest_country]['Renewable Water Resources (cu km)'])
        
        
        ans = np.asarray([src_country, dest_country,float(findDistance(lat1,lon1,lat2,lon2)), pop,life,lit,gdp,health, military,water])
        
        distance_.loc[len(distance_)+1] = ans
        #print(src_country, dest_country,findDistance(lat1,lon1,lat2,lon2))
distance_ = distance_[distance_['Country1']!=distance_['Country2']].sort(columns='Distance')
print ("Distance Table")
distance_

# %%
print("Shortest Distance Table")
dfDistance.groupby('Country1').first()

# %%
print("Farthest Distance Table")
dfDistance.groupby('Country1').last()
